# %%
import pandas as pd
from pathlib import Path

# %%
# read all csv with "combined" in the name
csv_files = Path('.').glob('*combined*.csv')
csv_files = [str(x) for x in csv_files]
csv_files
# Out:
# ['combined_metrics_finished_edges.csv',
#  'combined_metrics_finished_paths.csv',
#  'combined_metrics_unfinished_edges.csv',
#  'combined_metrics_unfinished_paths.csv']

# %%
dfs = {x: pd.read_csv(x) for x in csv_files}
for name, df in dfs.items():
    print(name)
    display(df)
    print(df.columns)
# Out:
# combined_metrics_finished_edges.csv
#        Unnamed: 0                                           edge  \
# 0               0                   ('Slavery', 'United_States')
# 1               1                           ('Life', 'Organism')
# 2               2              ('Mercury_%28planet%29', 'Venus')
# 3               3                ('12th_century', '2nd_century')
# 4               4  ('J._R._R._Tolkien', 'Roman_Catholic_Church')
# ...           ...                                            ...
# 60180       60180                   ('Ancient_Greece', 'Poetry')
# 60181       60181                       ('World_War_II', 'NATO')
# 60182       60182                        ('Liberalism', 'Latin')
# 60183       60183          ('Troop_sleeper', 'Refrigerator_car')
# 60184       60184                         ('Bolivia', 'Country')
#
#        mean_bert_score  mean_rating
# 0             0.193962     3.000000
# 1             0.313079     3.363636
# 2             0.508045     2.000000
# ...
