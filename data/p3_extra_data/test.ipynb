# %%
import pandas as pd
import glob

# %%
# load all csv files in the folder
df_list = {}
for filename in glob.glob('*.csv'):
    df_list[filename] = pd.read_csv(filename)

# %%
for k, v in df_list.items():
    print(k)
    display(v)
# Out:
# finished_paths_appended_metrics.csv
#        Unnamed: 0   hashedIpAddress            timestamp  durationInSec  \
# 0               0  6a3701d319fc3754  2011-02-15 03:26:49            166
# 1               1  3824310e536af032  2012-08-12 06:36:52             88
# 2               2  415612e93584d30e  2012-10-03 21:10:40            138
# 3               3  64dd5cd342e3780c  2010-02-08 07:25:25             37
# 4               4  015245d773376aab  2013-04-23 15:27:08            175
# ...           ...               ...                  ...            ...
# 51313       51313  15a13a1d66ef5456  2012-10-03 02:23:35             66
# 51314       51314  2ef7ac844cefda58  2011-03-16 05:42:18            165
# 51315       51315  12863abb7887f890  2013-11-22 04:42:52            228
# 51316       51316  19f8284371753362  2011-02-27 07:42:47             56
# 51317       51317  24b84602179de377  2011-10-09 01:11:41             30
#
# ...

# %%
df_unfin_app = df_list["unfinished_paths_appended_metrics.csv"]
display(df_unfin_app)
# Out:
#        Unnamed: 0  index   hashedIpAddress            timestamp  \
# 0               0      2  2b015fb8181c48f2  2011-02-07 15:00:19
# 1               1      4  53a53bc244e08a6a  2011-02-07 17:18:25
# 2               2      5  131600803df4895e  2011-02-07 17:42:37
# 3               3      6  486bb79910fe9dd2  2011-02-07 18:01:00
# 4               4      7  6d136e371e42474f  2011-02-07 18:07:50
# ...           ...    ...               ...                  ...
# 19656       19656  24869  109ed71f571d86e9  2014-01-15 12:00:12
# 19657       19657  24870  109ed71f571d86e9  2014-01-15 12:06:45
# 19658       19658  24872  2e09a7224600a7cd  2014-01-15 15:06:40
# 19659       19659  24873  60af9e2138051b96  2014-01-15 15:24:41
# 19660       19660  24874  1cf0cbb3281049ab  2014-01-15 21:54:01
#
#        durationInSec                                               path  \
# 0               1818     ['Malawi', 'Democracy', 'Alexander_the_Great']
# ...
