# %% [markdown]
# ### Import raw datasets

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

DATA_FOLDER = "../data/"
PATHS_AND_GRAPH = DATA_FOLDER + "wikispeedia_paths-and-graph/"
PATHS_FINISHED = PATHS_AND_GRAPH + "paths_finished.tsv"
PATHS_UNFINISHED = PATHS_AND_GRAPH + "paths_unfinished.tsv"

# data exploration
paths_finished = pd.read_csv(
    PATHS_FINISHED,
    sep="\t",
    header=None,
    names=["hashedIpAddress", "timestamp", "durationInSec", "path", "rating"],
    encoding="utf-8",
    skiprows=16,
).copy(deep=True)
paths_finished["timestamp"] = pd.to_datetime(paths_finished["timestamp"], unit="s")

paths_unfinished = pd.read_csv(
    PATHS_UNFINISHED,
    sep="\t",
    header=None,
    names=["hashedIpAddress", "timestamp", "durationInSec", "path", "target", "type"],
    encoding="utf-8",
    skiprows=17,
).copy(deep=True)
paths_unfinished["timestamp"] = pd.to_datetime(paths_unfinished["timestamp"], unit="s")

# Remove annoying future warnings in pandas and seaborn with new python versions
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
from feature_49_generation import add_time_per_edge, add_BERTscore_metric, add_sentence_similarity_metric, split_into_edges

# %% [markdown]
# #### Get metric 4: time per edge

# %%
add_time_per_edge(paths_finished)
# Out:
#         hashedIpAddress           timestamp  durationInSec  \
# 0      6a3701d319fc3754 2011-02-15 03:26:49            166
# 1      3824310e536af032 2012-08-12 06:36:52             88
# 2      415612e93584d30e 2012-10-03 21:10:40            138
# 3      64dd5cd342e3780c 2010-02-08 07:25:25             37
# 4      015245d773376aab 2013-04-23 15:27:08            175
# ...                 ...                 ...            ...
# 51313  15a13a1d66ef5456 2012-10-03 02:23:35             66
# 51314  2ef7ac844cefda58 2011-03-16 05:42:18            165
# 51315  12863abb7887f890 2013-11-22 04:42:52            228
# 51316  19f8284371753362 2011-02-27 07:42:47             56
# 51317  24b84602179de377 2011-10-09 01:11:41             30
#
#                                                     path  rating  path_length  \
# 0      14th_century;15th_century;16th_century;Pacific...     NaN            9
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0            5
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN            8
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN            4
# 4      14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0            7
# ...                                                  ...     ...          ...
# 51313                   Yagan;Ancient_Egypt;Civilization     NaN            3
# 51314  Yagan;Folklore;Brothers_Grimm;<;19th_century;C...     3.0            9
# 51315  Yagan;Australia;England;France;United_States;T...     NaN            7
# 51316  Yarralumla%2C_Australian_Capital_Territory;Aus...     1.0            4
# 51317                            Ziad_Jarrah;Germany;Jew     NaN            3
#
#        coarse_mean_time
# 0             18.444444
# 1             17.600000
# 2             17.250000
# 3              9.250000
# 4             25.000000
# ...                 ...
# 51313         22.000000
# 51314         18.333333
# 51315         32.571429
# 51316         14.000000
# 51317         10.000000
#
# [51318 rows x 7 columns]

# %% [markdown]
# #### Utility function in order to easily fetch an edge-based dataframe

# %%
edge_df = split_into_edges(paths_finished)
edge_df
# Out:
#                                                    edge
# 0                               (Kazakhstan, Time_zone)
# 1                                   (Germany, Augustus)
# 2                                       (Alcohol, Salt)
# 3                                     (Neon, Aluminium)
# 4                             (British_Isles, Iron_Age)
# ...                                                 ...
# 55142                       (Beatles_for_Sale, Germany)
# 55143                           (Carbon_dioxide, Argon)
# 55144  (Dinosaur, Cretaceous-Tertiary_extinction_event)
# 55145                   (Johnston_Atoll, Pacific_Ocean)
# 55146                           (Cataract, Ultraviolet)
#
# [55147 rows x 1 columns]

# %% [markdown]
# #### This is only for showing our old metric, but it won't be used

# %%
bert_result = add_BERTscore_metric(paths_finished, edge_df)
display(bert_result[0])
display(bert_result[1])
# Out:
# 100%|██████████| 51318/51318 [02:08<00:00, 400.02it/s]
# /home/laurent/micromamba/envs/ada/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/laurent/micromamba/envs/ada/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/laurent/Desktop/EPFL/Master/Semestre 3/ADA/ada-2023-project-adamants/p3_code/feature_49_generation.py:81: RuntimeWarning: Mean of empty slice
#   "mean_rating": [np.nanmean(a[:, 0]) for a in global_dict.values()],
#         hashedIpAddress           timestamp  durationInSec  \
# 0      6a3701d319fc3754 2011-02-15 03:26:49            166
# 1      3824310e536af032 2012-08-12 06:36:52             88
# 2      415612e93584d30e 2012-10-03 21:10:40            138
# 3      64dd5cd342e3780c 2010-02-08 07:25:25             37
# 4      015245d773376aab 2013-04-23 15:27:08            175
# ...                 ...                 ...            ...
# 51313  15a13a1d66ef5456 2012-10-03 02:23:35             66
# 51314  2ef7ac844cefda58 2011-03-16 05:42:18            165
# 51315  12863abb7887f890 2013-11-22 04:42:52            228
# 51316  19f8284371753362 2011-02-27 07:42:47             56
# 51317  24b84602179de377 2011-10-09 01:11:41             30
#
#                                                     path  rating  \
# 0      14th_century;15th_century;16th_century;Pacific...     NaN
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN
# 4      14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0
# ...                                                  ...     ...
# 51313                   Yagan;Ancient_Egypt;Civilization     NaN
# 51314  Yagan;Folklore;Brothers_Grimm;<;19th_century;C...     3.0
# 51315  Yagan;Australia;England;France;United_States;T...     NaN
# 51316  Yarralumla%2C_Australian_Capital_Territory;Aus...     1.0
# 51317                            Ziad_Jarrah;Germany;Jew     NaN
#
#                                          sucessive_pairs  \
# 0      [(14th_century, 15th_century), (15th_century, ...
# 1      [(14th_century, Europe), (Europe, Africa), (Af...
# 2      [(14th_century, Niger), (Niger, Nigeria), (Nig...
# 3      [(14th_century, Renaissance), (Renaissance, An...
# 4      [(14th_century, Italy), (Italy, Roman_Catholic...
# ...                                                  ...
# 51313  [(Yagan, Ancient_Egypt), (Ancient_Egypt, Civil...
# 51314  [(Yagan, Folklore), (Folklore, Brothers_Grimm)...
# 51315  [(Yagan, Australia), (Australia, England), (En...
# 51316  [(Yarralumla%2C_Australian_Capital_Territory, ...
# 51317           [(Ziad_Jarrah, Germany), (Germany, Jew)]
#
#                                  sucessive_pairs_encoded  BERTscore
# 0      [0.9999865336188821, 0.9996365919982175, 0.700...   0.728473
# 1      [0.9991989360002825, 0.9999737552461722, 0.999...   0.996099
# 2      [0.9996385206665049, 0.9999102184557794, 0.993...   0.918952
# 3      [0.9998434610819371, 0.9999529237925113, 0.999...   0.999921
# 4      [0.9996227605786427, 0.9994910726698206, 0.997...   0.864102
# ...                                                  ...        ...
# 51313           [0.8414925191386161, 0.6745653260705816]   0.758029
# 51314  [0.7061826798319183, 0.10386472073217597, 0.70...   0.668543
# 51315  [0.9795027929002406, 0.9999874136213855, 0.999...   0.947972
# 51316  [0.8427053940237842, 0.9968548124510662, 0.958...   0.932568
# 51317           [0.1679093532478396, 0.9976263133762415]   0.582768
#
# [51307 rows x 8 columns]
#                                                    edge  mean_bert_score  \
# 0                               (Kazakhstan, Time_zone)         0.998009
# 1                                   (Germany, Augustus)         0.997902
# 2                                       (Alcohol, Salt)         0.723050
# 3                                     (Neon, Aluminium)         0.187076
# 4                             (British_Isles, Iron_Age)         0.725868
# ...                                                 ...              ...
# 55142                       (Beatles_for_Sale, Germany)         0.998158
# 55143                           (Carbon_dioxide, Argon)         0.013619
# 55144  (Dinosaur, Cretaceous-Tertiary_extinction_event)         0.577140
# 55145                   (Johnston_Atoll, Pacific_Ocean)         0.392250
# 55146                           (Cataract, Ultraviolet)         0.919364
#
#        mean_rating
# 0         3.000000
# 1         4.000000
# 2         3.000000
# 3         3.000000
# 4         2.000000
# ...            ...
# 55142     2.000000
# 55143     3.666667
# 55144     1.500000
# 55145     2.000000
# 55146     4.000000
#
# [55147 rows x 3 columns]

# %% [markdown]
# #### Sentence-transformers based word-pair similarity metric

# %%
sim_result = add_sentence_similarity_metric(paths_finished, edge_df)
display(sim_result[0])
display(sim_result[1])
# Out:
# Batches:   0%|          | 0/66 [00:00<?, ?it/s]
# Starting loop
# Computing dot products: 100%|██████████| 51318/51318 [00:08<00:00, 5805.37it/s]
# /home/laurent/micromamba/envs/ada/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/laurent/micromamba/envs/ada/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/laurent/Desktop/EPFL/Master/Semestre 3/ADA/ada-2023-project-adamants/p3_code/feature_49_generation.py:144: RuntimeWarning: Mean of empty slice
#   "mean_rating": [np.nanmean(a[:, 0]) for a in global_dict.values()],
#         hashedIpAddress           timestamp  durationInSec  \
# 0      6a3701d319fc3754 2011-02-15 03:26:49            166
# 1      3824310e536af032 2012-08-12 06:36:52             88
# 2      415612e93584d30e 2012-10-03 21:10:40            138
# 3      64dd5cd342e3780c 2010-02-08 07:25:25             37
# 4      015245d773376aab 2013-04-23 15:27:08            175
# ...                 ...                 ...            ...
# 51313  15a13a1d66ef5456 2012-10-03 02:23:35             66
# 51314  2ef7ac844cefda58 2011-03-16 05:42:18            165
# 51315  12863abb7887f890 2013-11-22 04:42:52            228
# 51316  19f8284371753362 2011-02-27 07:42:47             56
# 51317  24b84602179de377 2011-10-09 01:11:41             30
#
#                                                     path  rating  \
# 0      14th_century;15th_century;16th_century;Pacific...     NaN
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN
# 4      14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0
# ...                                                  ...     ...
# 51313                   Yagan;Ancient_Egypt;Civilization     NaN
# 51314  Yagan;Folklore;Brothers_Grimm;<;19th_century;C...     3.0
# 51315  Yagan;Australia;England;France;United_States;T...     NaN
# 51316  Yarralumla%2C_Australian_Capital_Territory;Aus...     1.0
# 51317                            Ziad_Jarrah;Germany;Jew     NaN
#
#                                          sucessive_pairs  \
# 0      [(14th_century, 15th_century), (15th_century, ...
# 1      [(14th_century, Europe), (Europe, Africa), (Af...
# 2      [(14th_century, Niger), (Niger, Nigeria), (Nig...
# 3      [(14th_century, Renaissance), (Renaissance, An...
# 4      [(14th_century, Italy), (Italy, Roman_Catholic...
# ...                                                  ...
# 51313  [(Yagan, Ancient_Egypt), (Ancient_Egypt, Civil...
# 51314  [(Yagan, Folklore), (Folklore, Brothers_Grimm)...
# 51315  [(Yagan, Australia), (Australia, England), (En...
# 51316  [(Yarralumla%2C_Australian_Capital_Territory, ...
# 51317           [(Ziad_Jarrah, Germany), (Germany, Jew)]
#
#                                  sucessive_pairs_encoded  BERTscore
# 0      [0.843832790851593, 0.8465811014175415, 0.2658...   0.596161
# 1      [0.2547887861728668, 0.650822639465332, 0.3347...   0.528948
# 2      [0.22429414093494415, 0.7818886637687683, 0.39...   0.488120
# 3      [0.3987607955932617, 0.3302411437034607, 0.666...   0.465273
# 4      [0.17625783383846283, 0.30731645226478577, 0.2...   0.333869
# ...                                                  ...        ...
# 51313         [0.17201462388038635, 0.40563252568244934]   0.288824
# 51314  [0.2101505845785141, 0.29172438383102417, 0.21...   0.321190
# 51315  [0.12989801168441772, 0.7208418846130371, 0.62...   0.396291
# 51316  [0.44925427436828613, 0.41598689556121826, 0.4...   0.436014
# 51317         [0.11018940806388855, 0.30471211671829224]   0.207451
#
# [51307 rows x 8 columns]
#                                                    edge  mean_bert_score  \
# 0                               (Kazakhstan, Time_zone)         0.230465
# 1                                   (Germany, Augustus)         0.160548
# 2                                       (Alcohol, Salt)         0.492251
# 3                                     (Neon, Aluminium)         0.403407
# 4                             (British_Isles, Iron_Age)         0.365899
# ...                                                 ...              ...
# 55142                       (Beatles_for_Sale, Germany)         0.039925
# 55143                           (Carbon_dioxide, Argon)         0.281742
# 55144  (Dinosaur, Cretaceous-Tertiary_extinction_event)         0.454815
# 55145                   (Johnston_Atoll, Pacific_Ocean)         0.624163
# 55146                           (Cataract, Ultraviolet)         0.348307
#
#        mean_rating
# 0         3.000000
# 1         4.000000
# 2         3.000000
# 3         3.000000
# 4         2.000000
# ...            ...
# 55142     2.000000
# 55143     3.666667
# 55144     1.500000
# 55145     2.000000
# 55146     4.000000
#
# [55147 rows x 3 columns]
